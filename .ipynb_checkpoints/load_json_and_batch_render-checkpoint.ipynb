# %%
from PIL import Image

# %%
import json
with open("template.json") as file:
    config_dict = json.loads(file.read())

# %%
import pandas as pd
df = pd.read_excel("/Users/zhengyiming/PycharmProjects/id_card_editer/static/avatar/2023-12-26 13:31:57/工作簿1.xlsx")
df
# Out:
#    avatar      name          id
# 0       1     Lilei  1331131323
# 1       2      Jack  1331131325
# 2       3  SuperMan  1331131326

# %%
x, y = config_dict['background']['size']['width'], config_dict['background']['size']['height']
x, y
# Out:
# (642, 428)

# %%
config_dict['textList']
# Out:
# [{'position': {'left': 192, 'top': 208},
#   'content': 'name:',
#   'fontSize': '42px',
#   'color': 'rgb(151, 120, 120)',
#   'fontFamily': 'WithLogica-Rp7ml_otf',
#   'isTemplate': False,
#   'colName': ''},
#  {'position': {'left': 312, 'top': 207},
#   'content': 'ddafadfafafad',
#   'fontSize': '43px',
#   'color': 'rgb(255, 255, 255)',
#   'fontFamily': 'WithLogica-Rp7ml_otf',
#   'isTemplate': True,
#   'colName': 'name'},
#  {'position': {'left': 213, 'top': 267},
#   'content': 'id:',
#   'fontSize': '55px',
#   'color': 'rgb(151, 120, 120)',
#   'fontFamily': 'WithLogica-Rp7ml_otf',
#   'isTemplate': False,
#   'colName': None},
#  {'position': {'left': 289, 'top': 265},
#   'content': '1213123213',
#   'fontSize': '42px',
#   'color': 'rgb(224, 62, 62)',
#   'fontFamily': 'SabrinaDestiny-8M39B_ttf',
#   'isTemplate': True,
#   'colName': 'id'}]

# %%
import io
import base64

def pil_read_base64(string):
    # 假设这是你的 base64 编码的图片数据
    # 移除 base64 编码字符串中的前缀部分（...等）
    img_data = base64.b64decode(string.split(',')[1])
    # 将解码后的数据转换为字节流
    image_stream = io.BytesIO(img_data)
    image = Image.open(image_stream)
#     print(image.size)
    return image

backgroup_img =  pil_read_base64(config_dict['background']['imageUrl'])
# backgroup_img.resize() 
backgroup_img.save("background.png")

# %%
# backgroup_img.resize((x, y))

# %%
backgroup_img.size
# Out:
# (3072, 2048)

# %%
config_dict
# Out:
# {'background': {'size': {'width': 642, 'height': 428},
#   'imageUrl': 'url("data:image/jpeg;base64,...")'},
#  'avatar': {'imageUrl': '',
#   'size': {'width': '181px', 'height': '181px'},
#   'position': {'left': 237, 'top': 14},
#   'rounded': False,
#   'colName': 'avatar'},
#  'textList': [{'position': {'left': 192, 'top': 208},
#    'content': 'name:',
#    'fontSize': '42px',
#    'color': 'rgb(151, 120, 120)',
#    'fontFamily': 'WithLogica-Rp7ml_otf',
#    'isTemplate': False,
#    'colName': ''},
#   {'position': {'left': 312, 'top': 207},
#    'content': 'ddafadfafafad',
#    'fontSize': '43px',
#    'color': 'rgb(255, 255, 255)',
#    'fontFamily': 'WithLogica-Rp7ml_otf',
#    'isTemplate': True,
#    'colName': 'name'},
#   {'position': {'left': 213, 'top': 267},
#    'content': 'id:',
#    'fontSize': '55px',
#    'color': 'rgb(151, 120, 120)',
#    'fontFamily': 'WithLogica-Rp7ml_otf',
#    'isTemplate': False,
#    'colName': None},
#   {'position': {'left': 289, 'top': 265},
#    'content': '1213123213',
#    'fontSize': '42px',
#    'color': 'rgb(224, 62, 62)',
#    'fontFamily': 'SabrinaDestiny-8M39B_ttf',
#    'isTemplate': True,
#    'colName': 'id'}]}

# %%
# %time
from PIL import Image, ImageDraw, ImageFont
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
import base64, os

font_base_path = "/Users/zhengyiming/PycharmProjects/id_card_editer/static/fonts/"



def draw_text(image, fontname, fontsize, fontpose, fontcolor, content, font_base_path):  #fontpose(x,y)
    print(fontname, fontsize, fontpose, fontcolor, content)
    draw = ImageDraw.Draw(image)
#     font_base_path = "/Users/zhengyiming/PycharmProjects/id_card_editer/static/fonts/"
    font = ImageFont.truetype(os.path.join(font_base_path, fontname), fontsize)
    # 在指定位置添加文字
    draw.text(fontpose, content, fill=fontcolor, font=font, antialias=True)  # 在坐标 (50, 50) 处添加文字

def cut_avatar(image, size, is_radias=False):
    image = image.convert("RGBA")
    # 使用ImageOps模块的fit方法将图片缩放并居中裁剪，以适应元素大小
    result = ImageOps.fit(image, size, centering=(0.5, 0.5), method=Image.Resampling.BICUBIC) 
    if is_radias:
        mask = Image.new("L", result.size, 0)
        draw = ImageDraw.Draw(mask)
        draw.ellipse((0, 0) + result.size, fill=255)
        # 将遮罩应用到结果图片上，并保存
        result.putalpha(mask)
    return result
        
def paste_with_transparency(background, overlay, position):
    # 打开底图和叠加图
    # 确保图像都是 RGBA 模式，以支持透明度
    background = background.convert("RGBA")
    overlay = overlay.convert("RGBA")

    # 将叠加图粘贴到底图上
    background.paste(overlay, position, overlay)

    # 保存结果
#     background.save(output_path, format="PNG")
    return background
    
def render_image_by_config(df, config_dict, font_base_path, avatar_dir):
    base64_data = config_dict['background']['imageUrl']
    backgroup_img = pil_read_base64(base64_data)
    x, y = config_dict['background']['size']['width'], config_dict['background']['size']['height']
    
    background_resized_raw = backgroup_img.resize((x, y))
    
    # 创建一个可绘制对象
    templated = [i for i in config_dict['textList'] if i.get("isTemplate")]
    untemplated = [i for i in config_dict['textList'] if i.get("isTemplate") is False]

    # 读取头像数据模版配    
    image_filenames = [i for i in os.listdir(avatar_dir) if i.split(".")[-1] in ("png", "jpeg", "jpg", "gif")]
    image_dict = {i.split(".")[0]:i for i in image_filenames}  # 减少便利次数
    
    # 按行绘制模版填充的内容
    all_images = []
    for index, row in df.iterrows():
        row_dict = dict(row)
        background_resized = background_resized_raw.copy()
        # 读取图片
        avatar_dict = config_dict['avatar']
        avatar_filename = str(row_dict[avatar_dict['colName']])
        print(avatar_filename)
        print(image_dict)
        avatar_filename = image_dict[avatar_filename]
        print(avatar_filename)

        avatar_image = Image.open(os.path.join( avatar_dir , avatar_filename ))
        is_radias = avatar_dict['rounded']
        x, y = avatar_dict['position']['left'], avatar_dict['position']['top']
        avatar_position = (x, y)
        width = int(avatar_dict['size']['width'].strip("px"))
        height = int(avatar_dict['size']['height'].strip("px"))
        avatar_cut = cut_avatar(avatar_image, (width, height), is_radias=is_radias)
        
        background_resized = paste_with_transparency(background_resized, avatar_cut, avatar_position)
        
        for text_data in config_dict['textList']:
            is_template = text_data['isTemplate']
            col_name = text_data['colName']
            
            content = str(row_dict[col_name]) if is_template else text_data['content'] # 替换内容
            print("content", content)
            
            fontcolor = text_data['color']
            print("fontcolor", fontcolor)

            fontcolor = eval(fontcolor.replace("rgb", ""))

            fontsize = int(text_data['fontSize'].replace("px", ""))
            fontpose = (text_data['position']['left'], text_data['position']['top'])
            print(text_data['fontFamily'])
            fontname = text_data['fontFamily']

            fontname = fontname[0:-4] + "." + fontname[-3:-1] + fontname[-1]
            draw_text(background_resized, fontname, fontsize, fontpose, fontcolor, content, font_base_path)
        all_images.append(background_resized)
        # 保存修改后的图片
    # image.save("output.jpg")
    return all_images


font_base_path = "/Users/zhengyiming/PycharmProjects/id_card_editer/static/fonts"
avatar_dir = "/Users/zhengyiming/PycharmProjects/id_card_editer/static/avatar/2023-12-26 13:31:57"
images = render_image_by_config(df, config_dict, font_base_path, avatar_dir)
image

for i in images:
    plt.imshow(i)
    plt.show()
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.2 µs
# 1
# {'1': '1.jpeg', '2': '2.gif', '3': '3.jpg'}
# 1.jpeg
# content name:
# fontcolor rgb(151, 120, 120)
# WithLogica-Rp7ml_otf
# WithLogica-Rp7ml.otf 42 (192, 208) (151, 120, 120) name:
# content Lilei
# fontcolor rgb(255, 255, 255)
# WithLogica-Rp7ml_otf
# WithLogica-Rp7ml.otf 43 (312, 207) (255, 255, 255) Lilei
# content id:
# fontcolor rgb(151, 120, 120)
# WithLogica-Rp7ml_otf
# WithLogica-Rp7ml.otf 55 (213, 267) (151, 120, 120) id:
# content 1331131323
# fontcolor rgb(224, 62, 62)
# SabrinaDestiny-8M39B_ttf
# SabrinaDestiny-8M39B.ttf 42 (289, 265) (224, 62, 62) 1331131323
# 2
# {'1': '1.jpeg', '2': '2.gif', '3': '3.jpg'}
# 2.gif
# content name:
# fontcolor rgb(151, 120, 120)
# WithLogica-Rp7ml_otf
# WithLogica-Rp7ml.otf 42 (192, 208) (151, 120, 120) name:
# content Jack
# fontcolor rgb(255, 255, 255)
# WithLogica-Rp7ml_otf
# WithLogica-Rp7ml.otf 43 (312, 207) (255, 255, 255) Jack
# content id:
# fontcolor rgb(151, 120, 120)
# WithLogica-Rp7ml_otf
# WithLogica-Rp7ml.otf 55 (213, 267) (151, 120, 120) id:
# content 1331131325
# fontcolor rgb(224, 62, 62)
# SabrinaDestiny-8M39B_ttf
# SabrinaDestiny-8M39B.ttf 42 (289, 265) (224, 62, 62) 1331131325
# 3
# {'1': '1.jpeg', '2': '2.gif', '3': '3.jpg'}
# 3.jpg
# content name:
# fontcolor rgb(151, 120, 120)
# WithLogica-Rp7ml_otf
# WithLogica-Rp7ml.otf 42 (192, 208) (151, 120, 120) name:
# content SuperMan
# fontcolor rgb(255, 255, 255)
# WithLogica-Rp7ml_otf
# WithLogica-Rp7ml.otf 43 (312, 207) (255, 255, 255) SuperMan
# content id:
# fontcolor rgb(151, 120, 120)
# WithLogica-Rp7ml_otf
# WithLogica-Rp7ml.otf 55 (213, 267) (151, 120, 120) id:
# content 1331131326
# fontcolor rgb(224, 62, 62)
# SabrinaDestiny-8M39B_ttf
# SabrinaDestiny-8M39B.ttf 42 (289, 265) (224, 62, 62) 1331131326
